# %%
# Keras fix
import tensorflow
from tensorflow.python.ops import control_flow_ops
tensorflow.python.control_flow_ops = control_flow_ops

from keras.models import load_model
from nl.text_gen import generate_from_model
from nl.utils import load_w2v_data, GenerateSamples, print_word_list, parse_text
# Out:
# Using TensorFlow backend.
# /home/m20163692/anaconda3/envs/tf/lib/python3.5/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
print('Loading files...')

text_file = 'text_files/asimov'
model_file = 'models/asimov_model2.h5'
mode = 'general_1'

model = load_model(model_file)
seq_len = model.input_shape[1]
input_dim = model.input_shape[2]

word2idx, idx2word, embeddings = load_w2v_data('w2v_embs/asimov/asimov_vocab.json',
                                               'w2v_embs/asimov/asimov_embeddings.npz')
# Out:
# Loading files...

# %%
# Random samples from text_file
n_samples = 3
n_words = 150
print_truth = True
n_truth_words = 30
temperatures = [0.25, 0.5, 0.75]

samples = GenerateSamples(word2idx, text_file, mode, 'dir', n_samples, n_words)

for idx, sample in enumerate(samples):
    print('-' * 80)
    print('SAMPLE %d:' % (idx + 1))
    print_word_list(sample[:seq_len])
    
    if print_truth:
        print('\nTRUTH:')
        print_word_list(sample[:seq_len + n_truth_words])
    
    for temperature in temperatures:
        print('\nGENERATED FROM MODEL (temperature = %f):' % temperature)
        model_sample = generate_from_model(sample, model, embeddings, idx2word,
                                           word2idx, n_words, temperature, mode=mode)
        print_word_list(model_sample)
    
    print('-' * 80)
# Out:
# --------------------------------------------------------------------------------
# SAMPLE 1:
# mallow apagó su cigarro y no levantó la vista.
#  y cinco minutos después, jael se levantó y
#
# TRUTH:
# mallow apagó su cigarro y no levantó la vista.
#  y cinco minutos después, jael se levantó y dijo, preocupado:
#  — bueno, ahora que ha hecho usted un mártir para la causa, ¿qué pasará?
#  mallow dejó de jugar con el
#
# GENERATED FROM MODEL (temperature = 0.250000):
# mallow apagó su cigarro y no levantó la vista.
#  y cinco minutos después, jael se levantó y se sintió que el mulo se había dicho que el mulo se había dicho que el mulo no era el mulo.
#  — ¿qué es lo que se ha dicho?
#  — ¿qué?
#  — no.
#  — ¿por qué?
#  — no.
#  — ¿qué?
#  — ¿no es la la que no es un hombre?
#  — no.
#  — ¿y qué? — preguntó trevize.
#  — ¿y qué?
#  — no.
#  — ¿no es eso lo que no lo han dicho? — preguntó el doctor seldon.
#  — no lo sé.
#  — ¿no es eso lo que le han dicho?
#  — no.
#  — y ahora, ¿qué es lo que no es?
#  —
#
# GENERATED FROM MODEL (temperature = 0.500000):
# mallow apagó su cigarro y no levantó la vista.
#  y cinco minutos después, jael se levantó y se puso en pie.
#  — ¿quieres decir que, no quiero que me dijo que no le dijo nada que se habían en la tierra, y en la tierra, en un mundo de los mundos espaciales.
#  — ¿de qué? — preguntó trevize.
#  — no es muy bien, por supuesto — dijo trevize.
#  — ¿y no puedo usted que se ha visto de su usted?
#  — ¿no le han dicho que la
#  — no.
#  — ¿qué es lo que dijo, pero si no lo a usted, no lo sabe, no lo de lo que no lo había hecho en nada.
#  — ¿que lo han hecho?
#  — no, no es un gran la de las que los espaciales están en el
#
# GENERATED FROM MODEL (temperature = 0.750000):
# mallow apagó su cigarro y no levantó la vista.
#  y cinco minutos después, jael se levantó y se sintió que se él solo.
#  — es un poco que la la cada estoy durante el doctor mandamus de la mis — dijo el su, que sus palabras se había pasado —. y por favor — dijo bliss.
#  en su voz, la de un modo fue muy bastante para que la las luego se sintió entre los espaciales y los mundos que se habían hecho
#  de un modo tan..., su información, un poco más en un de su jander.
#  — ¿no está?
#  — usted no puede ser una que no lo ha dicho. se trata de un un poco a poco en que por un instante no la de para que trevize se nos dijo: « no es un hombre muy la una su ella y su la robots. la
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# SAMPLE 2:
# y allí estaba ella, harla branno, la más fuerte desde la muerte del mulo (ella lo sabía
#
# TRUTH:
# y allí estaba ella, harla branno, la más fuerte desde la muerte del mulo (ella lo sabía) y únicamente la quinta mujer en ocupar el cargo. sólo ese día había podido utilizar abiertamente su poder.
#  había luchado por su interpretación de lo que
#
# GENERATED FROM MODEL (temperature = 0.250000):
# y allí estaba ella, harla branno, la más fuerte desde la muerte del mulo (ella lo sabía, y no había podido ser.
#  — ¿qué?
#  — ¿y si no lo no le han dicho?
#  — no, no lo sé.
#  — ¿no es el mulo?
#  — ¿no lo sé?
#  — no.
#  — ¿no lo sé?
#  — no.
#  — ¿y qué?
#  — no.
#  — ¿y qué?
#  — ¿no es el mulo?
#  — ¿y qué?
#  — ¿no puede usted que se lo han dicho?
#  — no.
#  — ¿no es cierto que no lo sé?
#  — no.
#  — ¿y qué?
#  — no.
#  — ¿y qué? — preguntó trevize.
#  — no lo sé.
#
# GENERATED FROM MODEL (temperature = 0.500000):
# y allí estaba ella, harla branno, la más fuerte desde la muerte del mulo (ella lo sabía.
#  — ¿cómo lo dijo?
#  — no.
#  — ¿y qué? — preguntó trevize.
#  — no estoy seguro — dijo trevize.
#  — ¿quién es esto? — preguntó trevize.
#  — no lo sé — dijo bliss —. lo que yo he dicho es que no no puede nada de lo que no lo he dicho para la gente de la y lo que en la tierra?
#  — no, no es más que un mundo de los mundos espaciales.
#  — ¿por qué? — preguntó trevize.
#  — no es yo, ni un.
#  — ¿no es que no se los a la tierra?
#  — en efecto — repuso trevize —, pero no se trata de un lugar de la nave.
#
# GENERATED FROM MODEL (temperature = 0.750000):
# y allí estaba ella, harla branno, la más fuerte desde la muerte del mulo (ella lo sabía antes preguntó de qué se había de »
#  « ¿cómo no había el ello lo que había hecho?
# , y como no era el su efecto.
#  — ¿y ahora ya lo han hecho? — preguntó ella con la sonrisa de voz al mí.
#  — ya no es nada.
#  — ¿con sus palabras?
#  — por lo menos al no es en el poder a la puedo ver hay dos el mismo este hecho. por lo menos, no es muy para la el. si no lo se ha dicho, pero no es la una de las tres leyes de la nave.
#  — ¿es por la más?
#  — ¿único modo, pero no lo está?
#  — a que lo he dicho, que le he dicho
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# SAMPLE 3:
# — sí. ya puede imaginarse lo que sintió al verme tendida junto al cadáver de mi esposo.
#
# TRUTH:
# — sí. ya puede imaginarse lo que sintió al verme tendida junto al cadáver de mi esposo.
#  — me habían dicho que sólo visualizó el cadáver — observó baley.
#  — el cadáver, sí. pero, tras cerciorarse de que yo vivía y no
#
# GENERATED FROM MODEL (temperature = 0.250000):
# — sí. ya puede imaginarse lo que sintió al verme tendida junto al cadáver de mi esposo.
#  — ¿no es el caso que no lo han hecho?
#  — no.
#  — ¿cómo lo he dicho?
#  — no, no lo sé.
#  — ¿y qué es lo que yo he dicho?
#  — no.
#  — ¿y si no lo qué no es?
#  — ¿no es eso lo que no puede hacer?
#  — no.
#  — ¿y si no lo han dicho?
#  — no.
#  — ¿y si no lo que no lo han dicho?
#  — no.
#  — ¿y qué?
#  — es muy posible que no lo he dicho.
#  — ¿y qué?
#  — no.
#  — ¿y qué?
#  — no.
#  — ¿no es cierto que
#
# GENERATED FROM MODEL (temperature = 0.500000):
# — sí. ya puede imaginarse lo que sintió al verme tendida junto al cadáver de mi esposo.
#  — no es gran cosa que se ha dicho que no lo sé.
#  — ¿qué puedo hacer?
#  — no.
#  — ¿y qué?
#  — no es por lo menos. y si no lo hubiera hecho, el doctor mandamus, que no es un ser humano, no es un hombre que siempre me lo ha dicho.
#  — ¿qué que no le han dicho?
#  — no.
#  — ¿no es eso lo que no lo han dicho? — preguntó trevize.
#  — no.
#  — ¿qué?
#  — no. no es la una nave de la nave, pero no puede ser.
#  — ¿, amigo daneel, que no es un hombre?
#  — no, no es una nave.
#  —
#
# GENERATED FROM MODEL (temperature = 0.750000):
# — sí. ya puede imaginarse lo que sintió al verme tendida junto al cadáver de mi esposo.
#  — no podría ser que lo que te han dicho sobre un planeta, y no hay nada que la.
#  — supongo que me han dicho que no le han dicho que, aquel punto de — de la que una ser humano su una seldon no tiene nada de lo que ha sido los un mundo.
#  — ¿de qué su muy? — preguntó?
#  — ¿y si no fuese por el hecho de que su que no era estar a su las, que le dijo que iba a ser si no se lo había hecho.
#  — ¿cómo lo es?
#  — no.
#  — ¿sólo no los hombres nada ha sido, le usted? — preguntó trevize.
#  — como usted ha dicho — dijo raych con una sonrisa.
#  —
# --------------------------------------------------------------------------------

# %%
# Using custom text
text = 'El amanecer estaba apunto de comenzar'
n_words = 300
temperatures = [0.4, 0.5, 0.6]

print('SOURCE TEXT:\n%s' % text)

for temperature in temperatures:
    print('\nGENERATED FROM MODEL (temperature = %f):' % temperature)
    model_sample = generate_from_model(text, model, embeddings, idx2word, word2idx,
                                       n_words, temperature, truncating='post',
                                       custom_text=True, mode='general_2')
    print_word_list(model_sample)
# Out:
# SOURCE TEXT:
# El amanecer estaba apunto de comenzar
#
# GENERATED FROM MODEL (temperature = 0.400000):
# el amanecer estaba apunto de comenzar, con una de las manos, que se le han dicho que no había nada que se habían de su el lugar, en el que se lo he dicho.
#  — ¿y por qué?
#  — ¿y si no lo un hombre, en el que se trata de la que se lo he dicho es que no lo he dicho.
#  — ¿no es la que te la de la que le dijo:
#  — ¿qué es lo que yo he dicho, me han dicho que no le dijo nada, no lo había visto a su padre, y no lo estaba, no se podía ser una cosa que no había visto, no había ninguna.
#  — no es como lo que yo he dicho es que no lo sé, y no puedo hacer nada, no lo sé.
#  — ¿no puede usted decir que no se la me han dicho, que no lo sé.
#  — ¿y si no lo había dicho, los robots, que no lo había dicho, sí, no lo han dicho, si no he dicho que no lo no es muy bien.
#  — ¿es eso lo que no lo dijo, no se lo había dicho con un punto de a.
#  — ¿y qué es lo que había hecho, que no lo había dicho, ¿qué le han dicho que no lo hizo.
#  — ¿no es qué lo que he dicho es que no he podido de ver a los robots, no se lo había dicho, y se lo había dicho, su.
#
# GENERATED FROM MODEL (temperature = 0.500000):
# el amanecer estaba apunto de comenzar y que su un hombre había sido el más grande de la tierra, se sintió por un poco el tiempo que se había visto, no era un caso que no lo había dicho, ¿qué le dijo?
#  — ¿qué es lo que yo le dijo, lo mismo que no la había dicho al fin, su mi su es más que una la un ser humano, a una de las que se habían dicho, el caso que había en el espacio de la tierra, el robot se había dicho que era un hombre.
#  — ¿y no lo sé?
#  — no, no es la verdad.
#  — no, no, no lo que le han dicho, no es lo que lo que yo le he dicho es que no lo hizo.
#  — ¿y quién es el único que lo he dicho es que no lo he dicho. no es necesario que se lo ha hecho el señor de la noche, el mundo de la tierra, si no lo no lo de lo que le he dicho, no sé qué, no de no ser por el hecho de que el mulo, la
#  — ¿y cómo lo he dicho?
#  — no, no.
#  — ¿no es así?
#  — en efecto, ¿cómo es que no lo sabe, pero no es la de que no lo había hecho, no podía ser de nada, no podía evitar que el espacio de la tierra era el único que había hecho, el — y el que se había —, en el caso de que
#
# GENERATED FROM MODEL (temperature = 0.600000):
# el amanecer estaba apunto de comenzar, como si no lo muy cerca, no podía y, en primer lugar,, no el no lo sé, sí; no me lo he dicho.
#  — ¿qué?
#  — no.
#  — ¿no es así, primer orador, ya que su trabajo y la que se le ocurrió.
#  — ¿no es cierto que, más tarde, el ningún mundo
#  se sintió de un la de pero me gustaría que su — se a un hombre de la tierra, en el que se lo que he dicho, lo han hecho.
#  — entonces, ¿qué la y la su no se era tan como si no lo había dicho, mientras la un más de sus...
#  — nos han dicho que se lo han hecho, no lo no he dicho es que la voz era muy poco, se podía ver al mulo, no había podido en la situación, pero no había el uno de los más.
#  — ¿no puede usted ser lo que no es vez un poco de la la que se podía hacer era como si no lo había hecho, si no lo había dicho para su padre, que no había visto, señor, el tal no.
#  — ¿y si soy la algo que he visto en la tierra, y no había sido el mulo, que se había hecho fue la el el que, a lo largo de su el doctor mandamus se había de un hombre que había de con el gran una de sus que se habían de en el mundo de la tierra, de los que
